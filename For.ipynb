# %% [markdown]
# <a href="https://colab.research.google.com/github/dedewahyudii/While-For-Nested-Loop/blob/main/For.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Contoh pengulangan for sederhana
angka = [1,2,3,4,5]
for x in angka:
  print(x)

#Contoh pengulangan for
buah = ["nanas", "apel", "jeruk"]
for makanan in buah:
  print ("Saya suka makan", makanan)
# Out:
# 1
# 2
# 3
# 4
# 5
# Saya suka makan nanas
# Saya suka makan apel
# Saya suka makan jeruk
